# %%
import numpy as np

import pandas as pd

df = pd.read_csv(r"C:\Users\v_zor\PycharmProjects\KyleHardcode\curr_gantry.csv")

# df.x = df.x + 2
# df.y = df.y +1
# df.z = df.z - 1

print(df)

# df.to_csv(r"C:\Users\v_zor\PycharmProjects\KyleHardcode\curr_gantry.csv")
# Out:
#     Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0            key  \
# 0              0             0             0           0       midpoint
# 1              1             1             1           1     galvo_back
# 2              2             2             2           2       galvo_up
# 3              3             3             3           3          write
# 4              4             4             4           4        storage
# 5              5             5             5           5      shelf_one
# 6              6             6             6           6     shelf_swap
# 7              7             7             7           7    stationX_up
# 8              8             8             8           8  stationX_down
# 9              9             9             9           9       StationX
# 10            10            10            10          10      Terahertz
# 11            11            11            11          11      writeDrop
# ...
